# %% [markdown]
# # GaRField
#
# A Gaussian Random Field generator that produces multi-resolution realizations while preserving the large-scale Fourier modes of the original field.

# %% [markdown]
# ## Modules

# %%
# Matplotlib
import matplotlib.pyplot as plt

# Numpy
import numpy as np
from numpy.random import default_rng

# Scipy
from scipy.stats import norm

# Sys
import sys

# %%
# GaRField
sys.path.append("../garfield")
import gaussianrandomfield as gaussrf

# %% [markdown]
# ## GRF main

# %% [markdown]
# ### Parameters

# %% [markdown]
# grf_make = True to make new field
#
# grf_make = False to read from existing file

# %%
grf_make = True

# %% [markdown]
# IO

# %%
grf_dir  = "../data/"
grf_file = grf_dir + "grf.npy"

# %% [markdown]
# ND array shape

# %%
grf_shape = np.array((128, 128, 128))

# %% [markdown]
# Gaussian distribution: mean $\mu$ and variance $\sigma^2$

# %%
grf_mu    = 0.0
grf_sigma = 1.0

# %% [markdown]
# Integer seed for RNG

# %%
grf_seed = 1

# %% [markdown]
# ### Data

# %% [markdown]
# Init RNG with seed

# %%
rng = default_rng(grf_seed)

# %% [markdown]
# Generate new field or read from file

# %%
if (grf_make):
    grf = gaussrf.generate(grf_mu, grf_sigma, grf_shape, rng)
    print("Save", grf_file)
    np.save(grf_file, grf)
else:
    print("Load", grf_file)
    grf       = np.load(grf_file)
    grf_shape = grf.shape

# %% [markdown]
# Check statistics

# %%
print("Mean :", np.mean(grf.ravel()))
print("Std  :", np.std( grf.ravel()))

# %% [markdown]
# Plot distribution

# %%
xmax = grf_mu + 4*grf_sigma
xmin = grf_mu - 4*grf_sigma
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, grf_mu, grf_sigma)

plt.figure()
plt.hist(grf.ravel(), bins=100, density=True)
plt.plot(x, y, 'k')
plt.xlim(xmin, xmax)
plt.xlabel(r'$x$')
plt.ylabel('PDF')
plt.show()

# %% [markdown]
# ## GRF Low-resolution

# %% [markdown]
# ### Parameters

# %% [markdown]
# ND array shape

# %%
glr_shape = grf_shape//2

# %% [markdown]
# IO

# %%
glr_dir  = "../data/"
glr_file = glr_dir + "grf_lr.npy"

# %% [markdown]
# ### Data

# %% [markdown]
# Generate low-res GRF that preserves large-scale modes from base GRF

# %%
if (np.all(glr_shape <= grf_shape)):
    glr = gaussrf.decrease_resolution(grf, glr_shape)
else:
    print("Dimensions are incorrect")
    exit()

# %% [markdown]
# Save GRF low-res

# %%
print("Save", glr_file)
np.save(glr_file, glr)

# %% [markdown]
# Check moments

# %%
print("Mean :", np.mean(glr.ravel()))
print("Std  :", np.std( glr.ravel()))

# %% [markdown]
# Plot distribution

# %%
xmax = grf_mu + 4*grf_sigma
xmin = grf_mu - 4*grf_sigma
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, grf_mu, grf_sigma)

plt.figure()
plt.hist(glr.ravel(), bins=100, density=True)
plt.plot(x, y, 'k')
plt.xlim(xmin, xmax)
plt.xlabel(r'$x$')
plt.ylabel('PDF')
plt.show()

# %% [markdown]
# ## GRF High-resolution

# %% [markdown]
# ### Parameters

# %% [markdown]
# ND array shape

# %%
ghr_shape = grf_shape*2

# %% [markdown]
# IO

# %%
ghr_dir  = "../data/"
ghr_file = ghr_dir + "grf_hr.npy"

# %% [markdown]
# Integer seed for RNG

# %%
ghr_seed = 2

# %% [markdown]
# ## Data

# %% [markdown]
# Init RNG with seed

# %%
rng_hr = default_rng(ghr_seed)

# %% [markdown]
# Generate high-resolution GRF that preserves large-scale modes from base GRF

# %%
if (np.all(ghr_shape >= grf_shape)):
    ghr = gaussrf.increase_resolution(grf, ghr_shape, rng_hr)
else:
    print("Dimensions are incorrect")
    exit()

# %% [markdown]
# Save high-res GRF

# %%
print("Save", ghr_file)
np.save(ghr_file, ghr)

# %% [markdown]
# Check moments

# %%
print("Mean :", np.mean(ghr.ravel()))
print("Std  :", np.std( ghr.ravel()))

# %% [markdown]
# Plot distribution

# %%
xmax = grf_mu + 4*grf_sigma
xmin = grf_mu - 4*grf_sigma
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, grf_mu, grf_sigma)

plt.figure()
plt.hist(ghr.ravel(), bins=100, density=True)
plt.plot(x, y, 'k')
plt.xlim(xmin, xmax)
plt.xlabel(r'$x$')
plt.ylabel('PDF')
plt.show()
